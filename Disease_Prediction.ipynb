# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshita505/Prediction/blob/main/Disease_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
      import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)   pip install missingno

# %% [markdown]
# Uploading Data-set

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('HeartD.csv'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-5c5368d0-8969-418b-9c83-8776e0f14b11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c5368d0-8969-418b-9c83-8776e0f14b11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Reading the Data**

# %%
df=pd.read_csv("HeartD.csv")

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
import pandas as pd
import missingno as msno

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.shape
# Out:
# (319795, 18)

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['BMI'], vert=False, patch_artist=True)
plt.xlabel('BMI')
plt.title('Boxplot of BMI')
plt.show()

import matplotlib.pyplot as plt
plt.boxplot(df['SleepTime'], vert=False, patch_artist=True)
plt.xlabel('SleepTime')
plt.title('Boxplot of SleepTime')
plt.show()

# %%
from typing import Any
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')

for col in df.select_dtypes(include=['object']):
    plt.figure(figsize=(10, 6))  # Adjust figure size for better visibility
    sns.histplot(df[col], kde=True, bins=20)  # Increase bins for finer distribution
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
    plt.tight_layout()  # Adjust layout to prevent labels from overlapping
    plt.show()

# %%
sns.barplot(x='HeartDisease',y='BMI',data=df, palette='tab10')
# Out:
# <ipython-input-41-a017a4a71470>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='HeartDisease',y='BMI',data=df, palette='tab10')
# <Axes: xlabel='HeartDisease', ylabel='BMI'>

# %%
import seaborn as sns
# %matplotlib inline
sns.catplot(x='Sex',y='MentalHealth',data=df,kind='bar', palette='husl')
sns.catplot(x='HeartDisease',y='MentalHealth',data=df,kind='bar', palette='Set2')
sns.catplot(x='SkinCancer',y='MentalHealth',data=df,kind='bar', palette='rocket')
sns.catplot(x='GenHealth',y='MentalHealth',data=df,kind='bar', palette='Paired')
sns.catplot(x='Smoking',y='MentalHealth',data=df,kind='bar', palette='mako')
# Out:
# <ipython-input-113-1fd31242eda9>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Sex',y='MentalHealth',data=df,kind='bar', palette='husl')
# <ipython-input-113-1fd31242eda9>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='HeartDisease',y='MentalHealth',data=df,kind='bar', palette='Set2')
# <ipython-input-113-1fd31242eda9>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='SkinCancer',y='MentalHealth',data=df,kind='bar', palette='rocket')
# <ipython-input-113-1fd31242eda9>:6: FutureWarning:
#
# ...

# %%
sns.catplot(data=df, x="Smoking", y="MentalHealth", hue="GenHealth", kind="bar")

sns.catplot(data=df, x="Smoking", y="PhysicalHealth", hue="GenHealth", kind="bar")

# %%
# Import modules
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb


# Print data that will be plotted
# Columns shown here are selected by corr() since
# they are ideal for the plot
print(df.corr(numeric_only=True))

# Plotting correlation heatmap
dataplot = sb.heatmap(df.corr(numeric_only=True), cmap="YlGnBu", annot=True)

# Displaying heatmap
mp.show()
# Out:
#                      BMI  PhysicalHealth  MentalHealth  SleepTime
# BMI             1.000000        0.109788      0.064131  -0.051822
# PhysicalHealth  0.109788        1.000000      0.287987  -0.061387
# MentalHealth    0.064131        0.287987      1.000000  -0.119717
# SleepTime      -0.051822       -0.061387     -0.119717   1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    return np.sqrt(phi2 / min((k - 1), (r - 1)))

# Assuming 'data' is your DataFrame with categorical columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns

# Calculate Cramér's V for all pairs of categorical columns
corr_matrix = pd.DataFrame(index=categorical_cols, columns=categorical_cols)
for col1 in categorical_cols:
    for col2 in categorical_cols:
        corr_matrix.loc[col1, col2] = cramers_v(df[col1], df[col2])

# Create heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix.astype(float), annot=True, cmap='coolwarm', vmin=0, vmax=1)
plt.title("Cramér's V Correlation Matrix for Categorical Variables")
plt.show()

# %%
ax = sns.countplot(x='HeartDisease', data=df)
for bars in ax.containers:
  ax.bar_label(bars)
plt.show()

# %% [markdown]
# # MODEL PREPARATION

# %%
from sklearn.model_selection import train_test_split

# Assuming 'df' is your DataFrame and 'SkinCancer' is your target variable
X = df.drop('SkinCancer', axis=1)  # Features
y = df['SkinCancer']  # Target

# Convert categorical features to numerical using one-hot encoding (if needed)
X = pd.get_dummies(X, columns=['Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease', 'HeartDisease'])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42) # You can adjust test_size and random_state as needed

# Now you have X_train, X_test, y_train, and y_test ready for your ML model
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (214262, 50)
# X_test shape: (105533, 50)
# y_train shape: (214262,)
# y_test shape: (105533,)

# %%
X_test.head(), X_train.head()
# Out:
# (          BMI  PhysicalHealth  MentalHealth  SleepTime  Smoking_No  \
#  271884  27.63             0.0          25.0        7.0       False
#  270361  21.95             0.0          20.0        6.0        True
#  219060  31.32             0.0           0.0        6.0       False
#  24010   40.35            30.0           0.0        8.0        True
#  181930  35.61            30.0          30.0        4.0       False
#
#          Smoking_Yes  AlcoholDrinking_No  AlcoholDrinking_Yes  Stroke_No  \
#  271884         True                True                False       True
#  270361        False                True                False       True
#  219060         True                True                False       True
#  24010         False                True                False       True
#  181930         True                True                False       True
#
#          Stroke_Yes  ...  GenHealth_Fair  GenHealth_Good  GenHealth_Poor  \
# ...

# %%
X_test.shape , X_train.shape
# Out:
# ((105533, 50), (214262, 50))

# %%
# prompt: Random forest model

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Create a Random Forest classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)  # You can adjust n_estimators and other parameters

# Train the model
rf_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = rf_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8856755706745757
#               precision    recall  f1-score   support
#
#           No       0.91      0.97      0.94     95681
#          Yes       0.21      0.08      0.12      9852
#
#     accuracy                           0.89    105533
#    macro avg       0.56      0.53      0.53    105533
# weighted avg       0.85      0.89      0.86    105533

# %%
# Out:
# Model accuracy score with 100 decision-trees : 0.8846
